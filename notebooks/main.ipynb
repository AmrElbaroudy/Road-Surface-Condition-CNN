# %% [markdown]
# ### preparing data

# %%
# !uv run ../code/prepare_data.py
# Out:
# Saving 19329 images...

# %% [markdown]
# ### model training

# %%
# !uv run ../code/train.py
# Out:
# /bin/sh: line 1: uv: command not found
